# %% [markdown]
# <a href="https://colab.research.google.com/github/Daisy606/Python-exercise-2023/blob/main/%E5%8F%A3%E7%BD%A9%E8%B3%87%E6%96%99_API_%E4%B8%B2%E6%8E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json


# 利用 requests 對 API 來源發送一個請求
url = 'https://raw.githubusercontent.com/kiang/pharmacies/master/json/points.json'
response = requests.get(url)

# 將請求回應的內容存成一個字串格式
d = response.text

# 將長得像 json 格式的字串解析成字典或列表
data = json.loads(d)

#print(data)

#計算各地區的藥局數量
med_count = {}

# 填入欄位名稱
for d in data['features']:
    conunty = d['properties']['address'][:3]
    #print(d['properties']['county'])
    if conunty not in med_count:
        med_count[conunty] = 0
        print(med_count)
    if conunty  in med_count:
        med_count[conunty] =+ 1

#print(med_count)
# {'台北市': 123, '新北市': 456 ...}




print("FIN")
# Out:
# {'臺北市': 0}
# {'臺北市': 1, '高雄市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 1, '新北市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 1, '新北市': 1, '桃園市': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 1, '新北市': 1, '桃園市': 1, '新竹縣': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 1, '新北市': 1, '桃園市': 1, '新竹縣': 1, '宜蘭縣': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 1, '新北市': 1, '桃園市': 1, '新竹縣': 1, '宜蘭縣': 1, '苗栗縣': 0}
# {'臺北市': 1, '高雄市': 1, '臺中市': 1, '臺南市': 1, '基隆市': 1, '新竹市': 1, '嘉義市': 1, '新北市': 1, '桃園市': 1, '新竹縣': 1, '宜蘭縣': 1, '苗栗縣': 1, '彰化縣': 0}
# ...
